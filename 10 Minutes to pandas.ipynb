# %% [markdown]
# ## Object Creation

# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101', periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -1.048729 -0.414176 -0.002233  0.080306
# 2013-01-02  0.717843  0.052066  0.438007 -0.993281
# 2013-01-03 -0.208941 -0.377045 -0.205041  0.051637
# 2013-01-04  0.499321 -0.000845 -0.359559 -1.298627
# 2013-01-05 -0.773808 -1.156361 -0.840496 -0.384759
# 2013-01-06 -0.837841 -1.272365 -0.994201  2.219319

# %%
df2 = pd.DataFrame({'A': 1.,
   ...:                     'B': pd.Timestamp('20130102'),
   ...:                     'C': pd.Series(1, index=list(range(4)), dtype='float32'),
   ...:                     'D': np.array([3] * 4, dtype='int32'),
   ...:                     'E': pd.Categorical(["test", "train", "test", "train"]),
   ...:                     'F': 'foo'})
   ...: 
        
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df2.<TAB>  # noqa: E225, E999
df2.A                  df2.bool
df2.abs                df2.boxplot
df2.add                df2.C
df2.add_prefix         df2.clip
df2.add_suffix         df2.clip_lower
df2.align              df2.clip_upper
df2.all                df2.columns
df2.any                df2.combine
df2.append             df2.combine_first
df2.apply              df2.compound
df2.applymap           df2.consolidate
df2.D
# Out:
#   File "<ipython-input-12-09169a08e080>", line 2
#     df2.A                  df2.bool
#                              ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Viewing Data

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01 -1.048729 -0.414176 -0.002233  0.080306
# 2013-01-02  0.717843  0.052066  0.438007 -0.993281
# 2013-01-03 -0.208941 -0.377045 -0.205041  0.051637
# 2013-01-04  0.499321 -0.000845 -0.359559 -1.298627
# 2013-01-05 -0.773808 -1.156361 -0.840496 -0.384759

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04  0.499321 -0.000845 -0.359559 -1.298627
# 2013-01-05 -0.773808 -1.156361 -0.840496 -0.384759
# 2013-01-06 -0.837841 -1.272365 -0.994201  2.219319

# %%
df.index
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[-1.04872934e+00, -4.14175773e-01, -2.23280820e-03,
#          8.03064236e-02],
#        [ 7.17842873e-01,  5.20655853e-02,  4.38006776e-01,
#         -9.93280982e-01],
#        [-2.08941337e-01, -3.77044795e-01, -2.05041491e-01,
#          5.16370563e-02],
#        [ 4.99321236e-01, -8.44886217e-04, -3.59558678e-01,
#         -1.29862690e+00],
#        [-7.73807787e-01, -1.15636110e+00, -8.40496480e-01,
#         -3.84759272e-01],
#        [-8.37841133e-01, -1.27236506e+00, -9.94201117e-01,
#          2.21931860e+00]])

# %%
df2.values
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.275359 -0.528121 -0.327254 -0.054234
# std    0.742150  0.565514  0.532067  1.244019
# min   -1.048729 -1.272365 -0.994201 -1.298627
# 25%   -0.821833 -0.970815 -0.720262 -0.841151
# 50%   -0.491375 -0.395610 -0.282300 -0.166561
# 75%    0.322256 -0.094895 -0.052935  0.073139
# max    0.717843  0.052066  0.438007  2.219319

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A   -1.048729    0.717843   -0.208941    0.499321   -0.773808   -0.837841
# B   -0.414176    0.052066   -0.377045   -0.000845   -1.156361   -1.272365
# C   -0.002233    0.438007   -0.205041   -0.359559   -0.840496   -0.994201
# D    0.080306   -0.993281    0.051637   -1.298627   -0.384759    2.219319

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01  0.080306 -0.002233 -0.414176 -1.048729
# 2013-01-02 -0.993281  0.438007  0.052066  0.717843
# 2013-01-03  0.051637 -0.205041 -0.377045 -0.208941
# 2013-01-04 -1.298627 -0.359559 -0.000845  0.499321
# 2013-01-05 -0.384759 -0.840496 -1.156361 -0.773808
# 2013-01-06  2.219319 -0.994201 -1.272365 -0.837841

# %%
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2013-01-06 -0.837841 -1.272365 -0.994201  2.219319
# 2013-01-05 -0.773808 -1.156361 -0.840496 -0.384759
# 2013-01-01 -1.048729 -0.414176 -0.002233  0.080306
# 2013-01-03 -0.208941 -0.377045 -0.205041  0.051637
# 2013-01-04  0.499321 -0.000845 -0.359559 -1.298627
# 2013-01-02  0.717843  0.052066  0.438007 -0.993281

# %% [markdown]
# ## Selection

# %% [markdown]
# ### Getting

# %%
df['A']
# Out:
# 2013-01-01   -1.048729
# 2013-01-02    0.717843
# 2013-01-03   -0.208941
# 2013-01-04    0.499321
# 2013-01-05   -0.773808
# 2013-01-06   -0.837841
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01 -1.048729 -0.414176 -0.002233  0.080306
# 2013-01-02  0.717843  0.052066  0.438007 -0.993281
# 2013-01-03 -0.208941 -0.377045 -0.205041  0.051637

# %%
df['20130102':'20130104']
# Out:
#                    A         B         C         D
# 2013-01-02  0.717843  0.052066  0.438007 -0.993281
# 2013-01-03 -0.208941 -0.377045 -0.205041  0.051637
# 2013-01-04  0.499321 -0.000845 -0.359559 -1.298627

# %% [markdown]
# ### Selection by Label

# %%
df.loc[dates[0]]
# Out:
# A   -1.048729
# B   -0.414176
# C   -0.002233
# D    0.080306
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:, ['A', 'B']]
# Out:
#                    A         B
# 2013-01-01 -1.048729 -0.414176
# 2013-01-02  0.717843  0.052066
# 2013-01-03 -0.208941 -0.377045
# 2013-01-04  0.499321 -0.000845
# 2013-01-05 -0.773808 -1.156361
# 2013-01-06 -0.837841 -1.272365

# %%
df.loc['20130102':'20130104', ['A', 'B']]
# Out:
#                    A         B
# 2013-01-02  0.717843  0.052066
# 2013-01-03 -0.208941 -0.377045
# 2013-01-04  0.499321 -0.000845

# %%
df.loc['20130102', ['A', 'B']]
# Out:
# A    0.717843
# B    0.052066
# Name: 2013-01-02 00:00:00, dtype: float64

# %%
df.loc[dates[0], 'A']
# Out:
# -1.0487293394710224

# %%
df.at[dates[0], 'A']
# Out:
# -1.0487293394710224

# %% [markdown]
# ### Selection by Position

# %%
df.iloc[3]
# Out:
# A    0.499321
# B   -0.000845
# C   -0.359559
# D   -1.298627
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04  0.499321 -0.000845
# 2013-01-05 -0.773808 -1.156361

# %%
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                    A         C
# 2013-01-02  0.717843  0.438007
# 2013-01-03 -0.208941 -0.205041
# 2013-01-05 -0.773808 -0.840496

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02  0.717843  0.052066  0.438007 -0.993281
# 2013-01-03 -0.208941 -0.377045 -0.205041  0.051637

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01 -0.414176 -0.002233
# 2013-01-02  0.052066  0.438007
# 2013-01-03 -0.377045 -0.205041
# 2013-01-04 -0.000845 -0.359559
# 2013-01-05 -1.156361 -0.840496
# 2013-01-06 -1.272365 -0.994201

# %%
df.iloc[1, 1]
# Out:
# 0.05206558525060798

# %%
df.iat[1, 1]
# Out:
# 0.05206558525060798

# %% [markdown]
# ### Boolean Indexing

# %%
df[df.A > 0]
# Out:
#                    A         B         C         D
# 2013-01-02  0.717843  0.052066  0.438007 -0.993281
# 2013-01-04  0.499321 -0.000845 -0.359559 -1.298627

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01       NaN       NaN       NaN  0.080306
# 2013-01-02  0.717843  0.052066  0.438007       NaN
# 2013-01-03       NaN       NaN       NaN  0.051637
# 2013-01-04  0.499321       NaN       NaN       NaN
# 2013-01-05       NaN       NaN       NaN       NaN
# 2013-01-06       NaN       NaN       NaN  2.219319

# %%
df2 = df.copy()
df2['E'] = ['one', 'one', 'two', 'three', 'four', 'three']
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01 -1.048729 -0.414176 -0.002233  0.080306    one
# 2013-01-02  0.717843  0.052066  0.438007 -0.993281    one
# 2013-01-03 -0.208941 -0.377045 -0.205041  0.051637    two
# 2013-01-04  0.499321 -0.000845 -0.359559 -1.298627  three
# 2013-01-05 -0.773808 -1.156361 -0.840496 -0.384759   four
# 2013-01-06 -0.837841 -1.272365 -0.994201  2.219319  three

# %% [markdown]
# ### Setting

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range('20130102', periods=6))
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df['F'] = s1

# %%
df.at[dates[0], 'A'] = 0

# %%
df.iat[0, 1] = 0

# %%
df.loc[:, 'D'] = np.array([5] * len(df))

# %%
df
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -0.002233  5  NaN
# 2013-01-02  0.717843  0.052066  0.438007  5  1.0
# 2013-01-03 -0.208941 -0.377045 -0.205041  5  2.0
# 2013-01-04  0.499321 -0.000845 -0.359559  5  3.0
# 2013-01-05 -0.773808 -1.156361 -0.840496  5  4.0
# 2013-01-06 -0.837841 -1.272365 -0.994201  5  5.0

# %%
df2 = df.copy()

# %%
df2[df2 > 0] = -df2
df2
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -0.002233 -5  NaN
# 2013-01-02 -0.717843 -0.052066 -0.438007 -5 -1.0
# 2013-01-03 -0.208941 -0.377045 -0.205041 -5 -2.0
# 2013-01-04 -0.499321 -0.000845 -0.359559 -5 -3.0
# 2013-01-05 -0.773808 -1.156361 -0.840496 -5 -4.0
# 2013-01-06 -0.837841 -1.272365 -0.994201 -5 -5.0

# %% [markdown]
# ### Missing Data

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])
df1.loc[dates[0]:dates[1], 'E'] = 1
df1
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000 -0.002233  5  NaN  1.0
# 2013-01-02  0.717843  0.052066  0.438007  5  1.0  1.0
# 2013-01-03 -0.208941 -0.377045 -0.205041  5  2.0  NaN
# 2013-01-04  0.499321 -0.000845 -0.359559  5  3.0  NaN

# %%
df1.dropna(how='any')
# Out:
#                    A         B         C  D    F    E
# 2013-01-02  0.717843  0.052066  0.438007  5  1.0  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000 -0.002233  5  5.0  1.0
# 2013-01-02  0.717843  0.052066  0.438007  5  1.0  1.0
# 2013-01-03 -0.208941 -0.377045 -0.205041  5  2.0  5.0
# 2013-01-04  0.499321 -0.000845 -0.359559  5  3.0  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %% [markdown]
# ## Operations

# %% [markdown]
# ### Stats

# %%
df.mean()
# Out:
# A   -0.100571
# B   -0.459092
# C   -0.327254
# D    5.000000
# F    3.000000
# dtype: float64

# %%
df.mean(1)
# Out:
# 2013-01-01    1.249442
# 2013-01-02    1.441583
# 2013-01-03    1.241794
# 2013-01-04    1.627784
# 2013-01-05    1.245867
# 2013-01-06    1.379119
# Freq: D, dtype: float64

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis='index')
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -1.208941 -1.377045 -1.205041  4.0  1.0
# 2013-01-04 -2.500679 -3.000845 -3.359559  2.0  0.0
# 2013-01-05 -5.773808 -6.156361 -5.840496  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %% [markdown]
# ### Apply

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C   D     F
# 2013-01-01  0.000000  0.000000 -0.002233   5   NaN
# 2013-01-02  0.717843  0.052066  0.435774  10   1.0
# 2013-01-03  0.508902 -0.324979  0.230732  15   3.0
# 2013-01-04  1.008223 -0.325824 -0.128826  20   6.0
# 2013-01-05  0.234415 -1.482185 -0.969323  25  10.0
# 2013-01-06 -0.603426 -2.754550 -1.963524  30  15.0

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    1.555684
# B    1.324431
# C    1.432208
# D    0.000000
# F    4.000000
# dtype: float64

# %% [markdown]
# ### Histogramming

# %%
s = pd.Series(np.random.randint(0, 7, size=10))
s
# Out:
# 0    2
# 1    2
# 2    3
# 3    0
# 4    2
# 5    5
# 6    6
# 7    1
# 8    3
# 9    4
# dtype: int32

# %%
s.value_counts()
# Out:
# 2    3
# 3    2
# 6    1
# 5    1
# 4    1
# 1    1
# 0    1
# dtype: int64

# %% [markdown]
# ### String Methods

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %% [markdown]
# ## Merge

# %% [markdown]
# ### Concat

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0  0.429712  0.560466 -1.015102  0.265239
# 1  0.210719  0.229359  0.443433  0.525861
# 2  0.319182 -1.113866 -1.121566 -0.821799
# 3 -0.016505  0.026430  0.451548  2.060033
# 4 -1.486960 -1.658169 -1.148903 -0.001208
# 5 -1.288490 -0.649507 -2.516231 -1.000684
# 6  1.407014 -0.279198  1.237550 -0.680701
# 7 -0.707753  0.929164 -0.226693  1.081080
# 8  0.939151  1.073437  0.711484  0.516580
# 9  0.000079  0.322116  0.857726  1.754835

# %%
pieces = [df[:3], df[3:7], df[7:]]
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  0.429712  0.560466 -1.015102  0.265239
# 1  0.210719  0.229359  0.443433  0.525861
# 2  0.319182 -1.113866 -1.121566 -0.821799
# 3 -0.016505  0.026430  0.451548  2.060033
# 4 -1.486960 -1.658169 -1.148903 -0.001208
# 5 -1.288490 -0.649507 -2.516231 -1.000684
# 6  1.407014 -0.279198  1.237550 -0.680701
# 7 -0.707753  0.929164 -0.226693  1.081080
# 8  0.939151  1.073437  0.711484  0.516580
# 9  0.000079  0.322116  0.857726  1.754835

# %% [markdown]
# ### Join

# %%
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})

right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({'key': ['foo', 'bar'], 'lval': [1, 2]})

right = pd.DataFrame({'key': ['foo', 'bar'], 'rval': [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %% [markdown]
# ### Append

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=['A', 'B', 'C', 'D'])
df
# Out:
#           A         B         C         D
# 0 -1.314789 -0.458993  1.402776  0.416592
# 1 -1.456321  0.198150 -0.544611 -1.877505
# 2  0.756739 -0.275387 -0.356624  0.076731
# 3  0.620082 -0.687445 -0.377749  0.361454
# 4 -2.331590  0.300623  0.333503  0.319747
# 5 -0.366100  0.303870  0.604320  1.914739
# 6  0.566319  0.094577 -0.587366 -0.399724
# 7  0.653390  1.699023  0.742198  0.062350

# %%
s = df.iloc[3]

df.append(s, ignore_index=True)
# Out:
#           A         B         C         D
# 0 -1.314789 -0.458993  1.402776  0.416592
# 1 -1.456321  0.198150 -0.544611 -1.877505
# 2  0.756739 -0.275387 -0.356624  0.076731
# 3  0.620082 -0.687445 -0.377749  0.361454
# 4 -2.331590  0.300623  0.333503  0.319747
# 5 -0.366100  0.303870  0.604320  1.914739
# 6  0.566319  0.094577 -0.587366 -0.399724
# 7  0.653390  1.699023  0.742198  0.062350
# 8  0.620082 -0.687445 -0.377749  0.361454

# %% [markdown]
# ## Grouping

# %%
df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar',
   ....:                          'foo', 'bar', 'foo', 'foo'],
   ....:                    'B': ['one', 'one', 'two', 'three',
   ....:                          'two', 'two', 'one', 'three'],
   ....:                    'C': np.random.randn(8),
   ....:                    'D': np.random.randn(8)})

df
# Out:
#      A      B         C         D
# 0  foo    one  0.357944  0.173575
# 1  bar    one -1.669306  0.991560
# 2  foo    two -0.043338 -0.356102
# 3  bar  three  1.349667 -0.224316
# 4  foo    two  0.607558  1.235505
# 5  bar    two -0.181793 -1.639249
# 6  foo    one  0.065576  0.790841
# 7  foo  three -0.315987  0.070754

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar -0.501431 -0.872005
# foo  0.671753  1.914573

# %%
df.groupby(['A', 'B']).sum()
# Out:
#                   C         D
# A   B
# bar one   -1.669306  0.991560
#     three  1.349667 -0.224316
#     two   -0.181793 -1.639249
# foo one    0.423520  0.964416
#     three -0.315987  0.070754
#     two    0.564220  0.879403

# %% [markdown]
# ## Reshaping

# %% [markdown]
# ### Stack

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz',
   ....:                      'foo', 'foo', 'qux', 'qux'],
   ....:                     ['one', 'two', 'one', 'two',
   ....:                      'one', 'two', 'one', 'two']]))
   ....: 

index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])

df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])

df2 = df[:4]

df2
# Out:
#                      A         B
# first second
# bar   one    -0.674665 -0.818134
#       two     0.074198  2.464501
# baz   one     0.974980 -0.116330
#       two    -0.450028 -1.613232

# %%
stacked = df2.stack()
stacked
# Out:
# first  second
# bar    one     A   -0.674665
#                B   -0.818134
#        two     A    0.074198
#                B    2.464501
# baz    one     A    0.974980
#                B   -0.116330
#        two     A   -0.450028
#                B   -1.613232
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one    -0.674665 -0.818134
#       two     0.074198  2.464501
# baz   one     0.974980 -0.116330
#       two    -0.450028 -1.613232

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A -0.674665  0.074198
#       B -0.818134  2.464501
# baz   A  0.974980 -0.450028
#       B -0.116330 -1.613232

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A -0.674665  0.974980
#        B -0.818134 -0.116330
# two    A  0.074198 -0.450028
#        B  2.464501 -1.613232

# %% [markdown]
# ### Pivot Tables

# %%
df = pd.DataFrame({'A': ['one', 'one', 'two', 'three'] * 3,
   .....:                    'B': ['A', 'B', 'C'] * 4,
   .....:                    'C': ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
   .....:                    'D': np.random.randn(12),
   .....:                    'E': np.random.randn(12)})
   .....: 

df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -0.162813  0.903521
# 1     one  B  foo  0.524393 -0.741230
# 2     two  C  foo -0.084330 -0.560687
# 3   three  A  bar  0.323321 -0.738765
# 4     one  B  bar -0.065031 -0.876913
# 5     one  C  bar  1.113684  0.533878
# 6     two  A  foo -0.716235  1.907460
# 7   three  B  foo -0.228316 -0.978589
# 8     one  C  foo  2.707348  1.541610
# 9     one  A  bar  0.075738  0.316798
# 10    two  B  bar -2.871431 -0.208948
# 11  three  C  bar -0.988014  0.032562

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C             bar       foo
# A     B
# one   A  0.075738 -0.162813
#       B -0.065031  0.524393
#       C  1.113684  2.707348
# three A  0.323321       NaN
#       B       NaN -0.228316
#       C -0.988014       NaN
# two   A       NaN -0.716235
#       B -2.871431       NaN
#       C       NaN -0.084330

# %% [markdown]
# ## Time Series

# %%
rng = pd.date_range('1/1/2012', periods=100, freq='S')

ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

ts.resample('5Min').sum()
# Out:
# 2012-01-01    22913
# Freq: 5T, dtype: int32

# %%
rng = pd.date_range('3/6/2012 00:00', periods=5, freq='D')

ts = pd.Series(np.random.randn(len(rng)), rng)

ts
# Out:
# 2012-03-06   -1.378988
# 2012-03-07   -0.014057
# 2012-03-08    1.174335
# 2012-03-09   -0.961951
# 2012-03-10   -0.512127
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize('UTC')
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00   -1.378988
# 2012-03-07 00:00:00+00:00   -0.014057
# 2012-03-08 00:00:00+00:00    1.174335
# 2012-03-09 00:00:00+00:00   -0.961951
# 2012-03-10 00:00:00+00:00   -0.512127
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert('US/Eastern')
# Out:
# 2012-03-05 19:00:00-05:00   -1.378988
# 2012-03-06 19:00:00-05:00   -0.014057
# 2012-03-07 19:00:00-05:00    1.174335
# 2012-03-08 19:00:00-05:00   -0.961951
# 2012-03-09 19:00:00-05:00   -0.512127
# Freq: D, dtype: float64

# %%
rng = pd.date_range('1/1/2012', periods=5, freq='M')

ts = pd.Series(np.random.randn(len(rng)), index=rng)

ts
# Out:
# 2012-01-31    0.523849
# 2012-02-29   -0.959053
# 2012-03-31   -0.561958
# 2012-04-30   -0.983336
# 2012-05-31   -1.822469
# Freq: M, dtype: float64

# %%
ps = ts.to_period()
ps
# Out:
# 2012-01    0.523849
# 2012-02   -0.959053
# 2012-03   -0.561958
# 2012-04   -0.983336
# 2012-05   -1.822469
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2012-01-01    0.523849
# 2012-02-01   -0.959053
# 2012-03-01   -0.561958
# 2012-04-01   -0.983336
# 2012-05-01   -1.822469
# Freq: MS, dtype: float64

# %%
prng = pd.period_range('1990Q1', '2000Q4', freq='Q-NOV')

ts = pd.Series(np.random.randn(len(prng)), prng)

ts.index = (prng.asfreq('M', 'e') + 1).asfreq('H', 's') + 9

ts.head()
# Out:
# 1990-03-01 09:00   -0.121831
# 1990-06-01 09:00   -1.024478
# 1990-09-01 09:00    0.848316
# 1990-12-01 09:00   -0.332094
# 1991-03-01 09:00   -1.024885
# Freq: H, dtype: float64

# %%
df = pd.DataFrame({"id": [1, 2, 3, 4, 5, 6],
   .....:                    "raw_grade": ['a', 'b', 'b', 'a', 'a', 'e']})
   .....:

# %%
df["grade"] = df["raw_grade"].astype("category")

df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): [a, b, e]

# %%
df["grade"].cat.categories = ["very good", "good", "very bad"]

# %%
df["grade"] = df["grade"].cat.set_categories(["very bad", "bad", "medium",
   .....:                                               "good", "very good"])
   .....: 

df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): [very bad, bad, medium, good, very good]

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.groupby("grade").size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %% [markdown]
# ## Plotting

# %%
ts = pd.Series(np.random.randn(1000),
   .....:                index=pd.date_range('1/1/2000', periods=1000))
   .....: 

ts = ts.cumsum()

ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,
   .....:                   columns=['A', 'B', 'C', 'D'])
   .....: 

df = df.cumsum()

import matplotlib.pyplot as plt

plt.figure()
df.plot()
plt.legend(loc='best')

# %% [markdown]
# ## Getting Data In/Out

# %%
df.to_csv('D:/S1 Sistem Informasi ITS/Semester 8/Visualisasi Informasi/individu m12/foo.csv')

# %%
pd.read_csv('D:/S1 Sistem Informasi ITS/Semester 8/Visualisasi Informasi/individu m12/foo.csv')
# Out:
#      Unnamed: 0          A          B          C          D
# 0    2000-01-01  -1.610129  -0.781706  -0.128453   1.537512
# 1    2000-01-02  -0.656770   0.102337  -1.082949   1.122420
# 2    2000-01-03  -0.517274  -2.505341  -1.243339   2.908035
# 3    2000-01-04  -0.883260  -3.200144  -2.229122   3.242915
# 4    2000-01-05   2.397267  -1.807830  -2.841568   3.895579
# 5    2000-01-06   2.249141  -1.046008  -4.309740   3.494897
# 6    2000-01-07   3.412811  -0.740719  -4.149344   2.105836
# 7    2000-01-08   4.188221  -2.361938  -6.074694   1.573756
# 8    2000-01-09   4.119523  -4.237762  -5.102851   2.641112
# 9    2000-01-10   4.093259  -4.489113  -4.758727   2.502008
# 10   2000-01-11   3.899318  -4.737675  -5.579585   3.369200
# 11   2000-01-12   5.206961  -6.548732  -6.593571   3.718027
# 12   2000-01-13   5.456701  -5.598853  -6.057276   3.156558
# 13   2000-01-14   5.240325  -4.395844  -3.939701   3.184526
# 14   2000-01-15   5.223863  -5.580920  -2.644337   3.652131
# ...

# %% [markdown]
# ## HDF5

# %%
df.to_hdf('D:/S1 Sistem Informasi ITS/Semester 8/Visualisasi Informasi/individu m12/foo.h5', 'df')

# %%
pd.read_hdf('D:/S1 Sistem Informasi ITS/Semester 8/Visualisasi Informasi/individu m12/foo.h5', 'df')
# Out:
#                     A          B          C          D
# 2000-01-01  -1.610129  -0.781706  -0.128453   1.537512
# 2000-01-02  -0.656770   0.102337  -1.082949   1.122420
# 2000-01-03  -0.517274  -2.505341  -1.243339   2.908035
# 2000-01-04  -0.883260  -3.200144  -2.229122   3.242915
# 2000-01-05   2.397267  -1.807830  -2.841568   3.895579
# 2000-01-06   2.249141  -1.046008  -4.309740   3.494897
# 2000-01-07   3.412811  -0.740719  -4.149344   2.105836
# 2000-01-08   4.188221  -2.361938  -6.074694   1.573756
# 2000-01-09   4.119523  -4.237762  -5.102851   2.641112
# 2000-01-10   4.093259  -4.489113  -4.758727   2.502008
# 2000-01-11   3.899318  -4.737675  -5.579585   3.369200
# 2000-01-12   5.206961  -6.548732  -6.593571   3.718027
# 2000-01-13   5.456701  -5.598853  -6.057276   3.156558
# 2000-01-14   5.240325  -4.395844  -3.939701   3.184526
# 2000-01-15   5.223863  -5.580920  -2.644337   3.652131
# 2000-01-16   5.143181  -4.394007  -3.210306   2.971523
# ...

# %% [markdown]
# ## Excel

# %%
df.to_excel('D:/S1 Sistem Informasi ITS/Semester 8/Visualisasi Informasi/individu m12/foo.xlsx', sheet_name='Sheet1')

# %%
pd.read_excel('D:/S1 Sistem Informasi ITS/Semester 8/Visualisasi Informasi/individu m12/foo.xlsx', 'Sheet1', index_col=None, na_values=['NA'])
# Out:
#                     A          B          C          D
# 2000-01-01  -1.610129  -0.781706  -0.128453   1.537512
# 2000-01-02  -0.656770   0.102337  -1.082949   1.122420
# 2000-01-03  -0.517274  -2.505341  -1.243339   2.908035
# 2000-01-04  -0.883260  -3.200144  -2.229122   3.242915
# 2000-01-05   2.397267  -1.807830  -2.841568   3.895579
# 2000-01-06   2.249141  -1.046008  -4.309740   3.494897
# 2000-01-07   3.412811  -0.740719  -4.149344   2.105836
# 2000-01-08   4.188221  -2.361938  -6.074694   1.573756
# 2000-01-09   4.119523  -4.237762  -5.102851   2.641112
# 2000-01-10   4.093259  -4.489113  -4.758727   2.502008
# 2000-01-11   3.899318  -4.737675  -5.579585   3.369200
# 2000-01-12   5.206961  -6.548732  -6.593571   3.718027
# 2000-01-13   5.456701  -5.598853  -6.057276   3.156558
# 2000-01-14   5.240325  -4.395844  -3.939701   3.184526
# 2000-01-15   5.223863  -5.580920  -2.644337   3.652131
# 2000-01-16   5.143181  -4.394007  -3.210306   2.971523
# ...
